# %% [markdown]
# Mounting the Drive allows the notebook to access the dataset folder. You can see all the files in your Drive this way, but no one else can see them because a new VM is loaded each time.
#
# When you call `drive.mount()` you have to follow a link and sign into your Google account. Once you do, there is an authorization code that you enter in the notebook.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os 
os.listdir('gdrive/My Drive/CV-FinalProject/dataset/test/')
# Out:
# ['00280.png',
#  '00972.png',
#  '00023.png',
#  '00064.png',
#  '00073.png',
#  '00058.png',
#  '00105.png',
#  '00094.png',
#  '00102.png',
#  '00138.png',
#  '00157.png',
#  '00128.png',
#  '00174.png',
#  '00169.png',
#  '00204.png',
#  '00213.png',
#  '00208.png',
#  '00224.png',
#  '00284.png',
#  '00285.png',
#  '00351.png',
#  '00378.png',
#  '00435.png',
#  '00447.png',
#  '00430.png',
#  '00461.png',
#  '00503.png',
#  '00513.png',
#  '00548.png',
#  '00564.png',
#  '00551.png',
#  '00576.png',
#  '00589.png',
#  '00579.png',
#  '00612.png',
#  '00652.png',
#  '00704.png',
#  '00696.png',
#  '00701.png',
#  '00706.png',
#  '00719.png',
#  '00756.png',
#  '00768.png',
#  '00796.png',
#  '00795.png',
#  '00859.png',
#  '00857.png',
#  '00883.png',
#  '00899.png',
#  '00937.png',
#  '00946.png',
#  '00970.png',
#  '01032.png',
#  '01052.png',
#  '01061.png',
#  '01066.png',
#  '01073.png',
#  '01068.png',
#  '01083.png',
#  '01114.png',
#  '01127.png',
#  '01148.png',
# ...
